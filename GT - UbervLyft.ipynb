# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
gt_uber = pd.read_csv("Resources/Google Trends - Uber.csv")
gt_uber = gt_uber.set_index(["Year"])
gt_uber
# Out:
#       Butte/Placer/Shasta  Imperial  Los Angeles/Orange  San Diego  \
# Year
# 2013                  397       334                1820        623
# 2014                  198       401                3048        974
# 2015                  744       478                3553        709
# 2016                  443       512                4369       1065
# 2017                  926       596                2740        999
# 2018                  728       510                4270       1339
# 2019                  546       415                3142       1044
#
#       San Francisco
# Year
# 2013           1066
# 2014            964
# 2015            777
# 2016           1059
# 2017            893
# 2018           1268
# 2019            836

# %%
countynames_list = gt_uber.columns.values.tolist()
rideshareyears  = ['2013', '2014', '2015', '2016', '2017', '2018', '2019']
rural = ['Butte/Placer/Shasta','Imperial']
urban = ['Los Angeles/Orange','San Diego','San Francisco']

# %%
plt.plot(gt_uber[rural])
plt.xticks()
plt.title('Rural Google Trends for Uber (since Market Launch)')
plt.legend(rural,loc='best')
#set parameters for tick labels
plt.tick_params(axis='x', which='major', labelsize=7)
plt.tight_layout()

# %%
plt.plot(gt_uber[urban])
plt.xticks()
plt.title('Urban Google Trends for Uber (since Market Launch)')
plt.legend(urban,loc='best')
#set parameters for tick labels
plt.tick_params(axis='x', which='major', labelsize=7)
plt.tight_layout()

# %%
gt_lyft = pd.read_csv("Resources/Google Trends - Lyft.csv")
gt_lyft = gt_lyft.set_index(["Year"])
gt_lyft
# Out:
#       Butte/Placer/Shasta  Imperial  Los Angeles/Orange  San Diego  \
# Year
# 2013                  237       462                 581       1435
# 2014                  732       733                 711       3091
# 2015                 1348       734                 607       3619
# 2016                 2278      1548                1104       4013
# 2017                 2915      1812                 942       2995
# 2018                 2305      1767                1475       4090
# 2019                 2406      1461                1077       2937
#
#       San Francisco
# Year
# 2013           2462
# 2014           3283
# 2015           3581
# 2016           4256
# 2017           2806
# 2018           3640
# 2019           1987

# %%
countynames_list = gt_uber.columns.values.tolist()
rideshareyears  = ['2013', '2014', '2015', '2016', '2017', '2018', '2019']
rural = ['Butte/Placer/Shasta','Imperial']
urban = ['Los Angeles/Orange','San Diego','San Francisco']

# %%
plt.plot(gt_uber[rural])
plt.xticks()
plt.title('Rural Google Trends for Lyft (since Market Launch)')
plt.legend(rural,loc='best')
#set parameters for tick labels
plt.tick_params(axis='x', which='major', labelsize=7)
plt.tight_layout()

# %%
plt.plot(gt_uber[urban])
plt.xticks()
plt.title('Urban Google Trends for Lyft (since Market Launch)')
plt.legend(urban,loc='best')
#set parameters for tick labels
plt.tick_params(axis='x', which='major', labelsize=7)
plt.tight_layout()
